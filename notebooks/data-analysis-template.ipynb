# %% [markdown]
# # Python Fynesse Data Analysis Template
#
# ### 31st May 2021
#
# ### Neil D. Lawrence
#
# ### Updated 31st October 2021
#
# This notebook serves as a stub for the fynesse data analysis pipeline.

# %%
# %pip uninstall --yes fynesse
# Replace this with the location of your fynesse implementation.
# %pip install git+https://github.com/tomdunkley/advanced_data_science_assessment.git
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping fynesse as it is not installed.
# Collecting git+https://github.com/tomdunkley/advanced_data_science_assessment.git
#   Cloning https://github.com/tomdunkley/advanced_data_science_assessment.git to c:\users\torna\appdata\local\temp\pip-req-build-snt3zooc
#   Resolved https://github.com/tomdunkley/advanced_data_science_assessment.git to commit e2e92c3951c5067f683d62e65490227cfe6d507a
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ADS-Assessment==0.1.0) (1.5.2)
# Requirement already satisfied: numpy in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ADS-Assessment==0.1.0) (1.23.5)
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: matplotlib in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ADS-Assessment==0.1.0) (3.6.2)
# Requirement already satisfied: geopandas in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ADS-Assessment==0.1.0) (0.12.1)
# Requirement already satisfied: osmnx in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ADS-Assessment==0.1.0) (1.2.2)
# Collecting PyMySQL
#   Using cached PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Collecting ipython-sql
#   Using cached ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: PyYAML in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ADS-Assessment==0.1.0) (6.0)
# Requirement already satisfied: statsmodels in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ADS-Assessment==0.1.0) (0.13.5)
# Requirement already satisfied: sqlalchemy in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ADS-Assessment==0.1.0) (1.4.42)
# Requirement already satisfied: shapely in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ADS-Assessment==0.1.0) (1.8.5.post1)
# Requirement already satisfied: fiona>=1.8 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from geopandas->ADS-Assessment==0.1.0) (1.8.22)
# Requirement already satisfied: packaging in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from geopandas->ADS-Assessment==0.1.0) (21.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from geopandas->ADS-Assessment==0.1.0) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas->ADS-Assessment==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas->ADS-Assessment==0.1.0) (2022.6)
# Collecting sqlparse
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=1.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython-sql->ADS-Assessment==0.1.0) (8.7.0)
# Collecting prettytable<1
#   Downloading prettytable-0.7.2.zip (28 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ipython-genutils>=0.1.0
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: six in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython-sql->ADS-Assessment==0.1.0) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from sqlalchemy->ADS-Assessment==0.1.0) (1.1.3.post0)
# Requirement already satisfied: ipykernel in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jupyter->ADS-Assessment==0.1.0) (6.17.1)
# Collecting notebook
#   Downloading notebook-6.5.2-py3-none-any.whl (439 kB)
#      -------------------------------------- 439.1/439.1 kB 1.1 MB/s eta 0:00:00
# Collecting nbconvert
#   Downloading nbconvert-7.2.5-py3-none-any.whl (273 kB)
#      -------------------------------------- 273.3/273.3 kB 1.2 MB/s eta 0:00:00
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.2-py3-none-any.whl (134 kB)
#      -------------------------------------- 134.4/134.4 kB 1.1 MB/s eta 0:00:00
# Collecting qtconsole
#   Downloading qtconsole-5.4.0-py3-none-any.whl (121 kB)
#      -------------------------------------- 121.0/121.0 kB 1.2 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.4.4-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->ADS-Assessment==0.1.0) (2.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->ADS-Assessment==0.1.0) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->ADS-Assessment==0.1.0) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->ADS-Assessment==0.1.0) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->ADS-Assessment==0.1.0) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->ADS-Assessment==0.1.0) (4.38.0)
# Requirement already satisfied: Rtree>=1.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from osmnx->ADS-Assessment==0.1.0) (1.0.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from osmnx->ADS-Assessment==0.1.0) (2.8.8)
# Requirement already satisfied: requests>=2.28 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from osmnx->ADS-Assessment==0.1.0) (2.28.1)
# Requirement already satisfied: scipy>=1.3 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from statsmodels->ADS-Assessment==0.1.0) (1.8.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from statsmodels->ADS-Assessment==0.1.0) (0.5.3)
# Requirement already satisfied: cligj>=0.5 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from fiona>=1.8->geopandas->ADS-Assessment==0.1.0) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from fiona>=1.8->geopandas->ADS-Assessment==0.1.0) (1.1.1)
# Requirement already satisfied: attrs>=17 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from fiona>=1.8->geopandas->ADS-Assessment==0.1.0) (22.1.0)
# Requirement already satisfied: certifi in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from fiona>=1.8->geopandas->ADS-Assessment==0.1.0) (2020.6.20)
# Requirement already satisfied: click>=4.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from fiona>=1.8->geopandas->ADS-Assessment==0.1.0) (8.0.3)
# Requirement already satisfied: munch in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from fiona>=1.8->geopandas->ADS-Assessment==0.1.0) (2.5.0)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\site-packages (from fiona>=1.8->geopandas->ADS-Assessment==0.1.0) (56.0.0)
# Requirement already satisfied: pickleshare in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (0.7.5)
# Requirement already satisfied: decorator in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (0.18.2)
# Requirement already satisfied: traitlets>=5 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (5.6.0)
# Requirement already satisfied: backcall in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (2.13.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (3.0.33)
# Requirement already satisfied: colorama in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (0.4.4)
# Requirement already satisfied: matplotlib-inline in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (0.1.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.28->osmnx->ADS-Assessment==0.1.0) (1.25.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.28->osmnx->ADS-Assessment==0.1.0) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.28->osmnx->ADS-Assessment==0.1.0) (2.1.1)
# Requirement already satisfied: nest-asyncio in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipykernel->jupyter->ADS-Assessment==0.1.0) (1.5.6)
# Requirement already satisfied: psutil in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipykernel->jupyter->ADS-Assessment==0.1.0) (5.9.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipykernel->jupyter->ADS-Assessment==0.1.0) (7.4.7)
# Requirement already satisfied: debugpy>=1.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipykernel->jupyter->ADS-Assessment==0.1.0) (1.6.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipykernel->jupyter->ADS-Assessment==0.1.0) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from ipykernel->jupyter->ADS-Assessment==0.1.0) (24.0.1)
# Collecting jupyterlab-widgets~=3.0
#   Downloading jupyterlab_widgets-3.0.3-py3-none-any.whl (384 kB)
#      -------------------------------------- 384.1/384.1 kB 1.1 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0
#   Downloading widgetsnbextension-4.0.3-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from nbconvert->jupyter->ADS-Assessment==0.1.0) (4.11.1)
# Collecting nbformat>=5.1
#   Downloading nbformat-5.7.0-py3-none-any.whl (77 kB)
#      -------------------------------------- 77.1/77.1 kB 857.2 kB/s eta 0:00:00
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from nbconvert->jupyter->ADS-Assessment==0.1.0) (2.0.1)
# Collecting bleach
#   Downloading bleach-5.0.1-py3-none-any.whl (160 kB)
#      -------------------------------------- 160.9/160.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from nbconvert->jupyter->ADS-Assessment==0.1.0) (5.1.0)
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from nbconvert->jupyter->ADS-Assessment==0.1.0) (4.11.1)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.7.2-py3-none-any.whl (71 kB)
#      ---------------------------------------- 72.0/72.0 kB 1.3 MB/s eta 0:00:00
# Collecting mistune<3,>=2.0.3
#   Downloading mistune-2.0.4-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=3.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from nbconvert->jupyter->ADS-Assessment==0.1.0) (3.0.3)
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.17.0-py3-none-any.whl (16 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.15.0-py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.1/60.1 kB 1.6 MB/s eta 0:00:00
# Collecting nbclassic>=0.4.7
#   Downloading nbclassic-0.4.8-py3-none-any.whl (9.8 MB)
#      ---------------------------------------- 9.8/9.8 MB 1.2 MB/s eta 0:00:00
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.0-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.6/83.6 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from importlib-metadata>=3.6->nbconvert->jupyter->ADS-Assessment==0.1.0) (3.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->ADS-Assessment==0.1.0) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jupyter-core>=4.7->nbconvert->jupyter->ADS-Assessment==0.1.0) (2.5.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jupyter-core>=4.7->nbconvert->jupyter->ADS-Assessment==0.1.0) (305)
# Collecting jupyter-server>=1.8
#   Downloading jupyter_server-1.23.3-py3-none-any.whl (346 kB)
#      -------------------------------------- 346.4/346.4 kB 1.2 MB/s eta 0:00:00
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ---------------------------------------- 90.4/90.4 kB 1.0 MB/s eta 0:00:00
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: wcwidth in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (0.2.5)
# Collecting pywinpty>=1.1.0
#   Downloading pywinpty-2.0.9-cp38-none-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 1.2 MB/s eta 0:00:00
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from beautifulsoup4->nbconvert->jupyter->ADS-Assessment==0.1.0) (2.0.1)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from stack-data->ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from stack-data->ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (2.2.0)
# Requirement already satisfied: pure-eval in c:\users\torna\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from stack-data->ipython>=1.0->ipython-sql->ADS-Assessment==0.1.0) (0.2.2)
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.2-cp38-cp38-win_amd64.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB 1.1 MB/s eta 0:00:00
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
#      -------------------------------------- 55.3/55.3 kB 958.0 kB/s eta 0:00:00
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      -------------------------------------- 80.6/80.6 kB 902.3 kB/s eta 0:00:00
# Collecting cffi>=1.0.1
#   Downloading cffi-1.15.1-cp38-cp38-win_amd64.whl (178 kB)
#      -------------------------------------- 178.8/178.8 kB 1.2 MB/s eta 0:00:00
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      -------------------------------------- 118.7/118.7 kB 1.2 MB/s eta 0:00:00
# Building wheels for collected packages: ADS-Assessment, prettytable
#   Building wheel for ADS-Assessment (setup.py): started
#   Building wheel for ADS-Assessment (setup.py): finished with status 'done'
#   Created wheel for ADS-Assessment: filename=ADS_Assessment-0.1.0-py3-none-any.whl size=8152 sha256=1623a7ece1d08c0cb94e282bd1d924f539a726107f9e77e113f17d01bd3890aa
#   Stored in directory: C:\Users\torna\AppData\Local\Temp\pip-ephem-wheel-cache-okapm22w\wheels\5d\93\b8\46eb41c3a75c38778d08626e49768af2629f85038b2592f69c
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13699 sha256=4475783051ebda266048f1bf7461372ec77a389549bbcc6dc9c839ec0ca369df
#   Stored in directory: c:\users\torna\appdata\local\pip\cache\wheels\a9\b2\00\2e9bd731e2b62d0bc8bf73b24c149cd42b823982684fb2ccb9
# Successfully built ADS-Assessment prettytable
# Installing collected packages: webencodings, Send2Trash, prettytable, mistune, ipython-genutils, fastjsonschema, widgetsnbextension, websocket-client, tinycss2, sqlparse, sniffio, pywinpty, pyrsistent, PyMySQL, pycparser, prometheus-client, pkgutil-resolve-name, pandocfilters, jupyterlab-widgets, jupyterlab-pygments, importlib-resources, defusedxml, bleach, terminado, qtpy, jsonschema, cffi, anyio, nbformat, argon2-cffi-bindings, nbclient, ipython-sql, argon2-cffi, qtconsole, nbconvert, jupyter-console, ipywidgets, jupyter-server, notebook-shim, nbclassic, notebook, jupyter, ADS-Assessment
# Successfully installed ADS-Assessment-0.1.0 PyMySQL-1.0.2 Send2Trash-1.8.0 anyio-3.6.2 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 bleach-5.0.1 cffi-1.15.1 defusedxml-0.7.1 fastjsonschema-2.16.2 importlib-resources-5.10.0 ipython-genutils-0.2.0 ipython-sql-0.4.1 ipywidgets-8.0.2 jsonschema-4.17.3 jupyter-1.0.0 jupyter-console-6.4.4 jupyter-server-1.23.3 jupyterlab-pygments-0.2.2 jupyterlab-widgets-3.0.3 mistune-2.0.4 nbclassic-0.4.8 nbclient-0.7.2 nbconvert-7.2.5 nbformat-5.7.0 notebook-6.5.2 notebook-shim-0.2.2 pandocfilters-1.5.0 pkgutil-resolve-name-1.3.10 prettytable-0.7.2 prometheus-client-0.15.0 pycparser-2.21 pyrsistent-0.19.2 pywinpty-2.0.9 qtconsole-5.4.0 qtpy-2.3.0 sniffio-1.3.0 sqlparse-0.4.3 terminado-0.17.0 tinycss2-1.2.1 webencodings-0.5.1 websocket-client-1.4.2 widgetsnbextension-4.0.3
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/tomdunkley/advanced_data_science_assessment.git 'C:\Users\torna\AppData\Local\Temp\pip-req-build-snt3zooc'
#   WARNING: The script send2trash.exe is installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wsdump.exe is installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sqlformat.exe is installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script qtpy.exe is installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jsonschema.exe is installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-trust.exe is installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-execute.exe is installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-dejavu.exe and jupyter-nbconvert.exe are installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-console.exe is installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-server.exe is installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-nbclassic-bundlerextension.exe, jupyter-nbclassic-extension.exe, jupyter-nbclassic-serverextension.exe and jupyter-nbclassic.exe are installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-bundlerextension.exe, jupyter-nbextension.exe, jupyter-notebook.exe and jupyter-serverextension.exe are installed in 'C:\Users\torna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import fynesse

# %%
fynesse.access.config['data_url']

# %%
latitude, longitude = 50.7693314, 0.1285943
date = "2021-11-29"
property_type = 'F'
fynesse.predict_price(latitude, longitude, date, property_type)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 date = "2021-11-29"
#       3 property_type = 'F'
# ----> 4 fynesse.predict_price(latitude, longitude, date, property_type)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\fynesse\__init__.py:5, in predict_price(date_str, lattitude, longitude, property_type)
#       4 def predict_price(date_str, lattitude, longitude, property_type):
# ----> 5     return address.predict_price(date_str, lattitude, longitude, property_type)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\fynesse\address.py:11, in predict_price(date_str, lattitude, longitude, property_type)
#      10 def predict_price(date_str, lattitude, longitude, property_type):
# ---> 11     df, property_types, road_types, schools, osm_data, roads = assess.data()
#      12     school_distance = access.distance_to_nearest_school(lattitude, longitude, schools)
#      13     nearby_building_count = access.building_count(lattitude, longitude, osm_data)
#
# TypeError: data() missing 4 required positional arguments: 'lat', 'lon', 'date_str', and 'bbox_size'
